# %% [markdown]
# # TP 3 — Data Structures: Lists and Dictionaries
#
# **Module**: Programmation Python — ELNI 5.5
# **Chapter**: 3 — Data Structures
# **Estimated time**: 90–120 minutes
#
# ---
#
# ## Scenario
#
# You are processing data from a small monitoring network installed on a construction site. The network has two sensors (S1 and S2) recording temperature and pressure every 15 minutes. The raw data is provided as a list of dictionaries, mirroring what you would load from `assets/sensor_data.csv` (which you will do formally in Chapter 5).
#
# Your tasks include: cleaning the data, computing statistics, building summary reports, and storing configuration in dictionaries.

# %%
# Shared dataset — used across all exercises. Do not modify.
sensor_data = [
    {"timestamp": "2024-01-15 08:00:00", "sensor_id": "S1", "temperature_c": 22.3, "pressure_kpa": 101.2, "status": "OK"},
    {"timestamp": "2024-01-15 08:00:00", "sensor_id": "S2", "temperature_c": 23.1, "pressure_kpa": 101.5, "status": "OK"},
    {"timestamp": "2024-01-15 08:15:00", "sensor_id": "S1", "temperature_c": 22.8, "pressure_kpa": 101.3, "status": "OK"},
    {"timestamp": "2024-01-15 08:15:00", "sensor_id": "S2", "temperature_c": 23.4, "pressure_kpa": 101.4, "status": "OK"},
    {"timestamp": "2024-01-15 08:30:00", "sensor_id": "S1", "temperature_c": 23.2, "pressure_kpa": 101.1, "status": "OK"},
    {"timestamp": "2024-01-15 08:30:00", "sensor_id": "S2", "temperature_c": -999.0, "pressure_kpa": 101.6, "status": "ERROR"},
    {"timestamp": "2024-01-15 08:45:00", "sensor_id": "S1", "temperature_c": 23.5, "pressure_kpa": 101.0, "status": "OK"},
    {"timestamp": "2024-01-15 08:45:00", "sensor_id": "S2", "temperature_c": 24.1, "pressure_kpa": 101.7, "status": "OK"},
    {"timestamp": "2024-01-15 09:00:00", "sensor_id": "S1", "temperature_c": 24.0, "pressure_kpa": 100.9, "status": "OK"},
    {"timestamp": "2024-01-15 09:00:00", "sensor_id": "S2", "temperature_c": 24.3, "pressure_kpa": 101.8, "status": "OK"},
]
print(f"Dataset loaded: {len(sensor_data)} records")

# %% [markdown]
# ---
#
# ## Exercise 1 — List Basics: Extraction and Inspection
#
# **Objective**: Index, slice, and inspect a list.
#
# From `sensor_data`:
# 1. Print the first record using index 0.
# 2. Print the last record using a negative index.
# 3. Print a slice of records 3 through 5 (inclusive).
# 4. Create a flat list called `all_temperatures` containing every `temperature_c` value from all 10 records.
# 5. Print `all_temperatures`, its length, minimum, maximum, and sum.

# %%
# TODO 1: Print sensor_data[0]

# TODO 2: Print the last record

# TODO 3: Print sensor_data[2:5] (slice for records at index 2, 3, 4)

# TODO 4: Build all_temperatures — a list of every temperature_c value
# Hint: use a list comprehension

# TODO 5: Print length, min, max, sum of all_temperatures

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 2 — List Methods: Data Cleaning
#
# **Objective**: Use list methods to modify and clean a list.
#
# Starting with the `all_temperatures` list from Exercise 1:
#
# 1. Create a copy called `cleaned` (use `cleaned = all_temperatures.copy()`).
# 2. Use `.remove()` to remove the faulty value `-999.0` from `cleaned`.
# 3. Sort `cleaned` in ascending order.
# 4. Print the sorted `cleaned` list.
# 5. Use `sorted()` (not `.sort()`) to create a **descending** sorted version called `cleaned_desc`, without modifying `cleaned`.
# 6. Print both `cleaned` (ascending) and `cleaned_desc` (descending) to verify they are separate lists.
# 7. Print the new min, max, and average of `cleaned` after removing the fault.

# %%
# TODO 1: copy all_temperatures into cleaned

# TODO 2: remove -999.0 from cleaned

# TODO 3: sort cleaned in ascending order (in place)

# TODO 4: print cleaned

# TODO 5: create cleaned_desc using sorted() with reverse=True

# TODO 6: print both lists

# TODO 7: print new min, max, average

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 3 — List Comprehensions
#
# **Objective**: Use list comprehensions for filtering and transformation.
#
# Using `sensor_data` and list comprehensions:
#
# 1. Build `valid_readings` — all records where `status == "OK"` and `temperature_c > -100`.
# 2. Build `s1_temps` — a list of all valid temperature_c values for sensor S1 only.
# 3. Build `temps_fahrenheit` — a list of the same S1 temperatures converted to Fahrenheit (°F = °C × 9/5 + 32).
# 4. Build `above_23` — a list of timestamps where the temperature was above 23.0 °C and the status was OK.
# 5. Print all four lists and the count of items in each.

# %%
# TODO 1: valid_readings — list comprehension filtering out ERROR records

# TODO 2: s1_temps — temperatures for S1 valid readings only

# TODO 3: temps_fahrenheit — S1 temps in Fahrenheit

# TODO 4: above_23 — timestamps where temp > 23.0 and status == OK

# TODO 5: Print all results with counts

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 4 — Dictionaries: Sensor Configuration
#
# **Objective**: Create, access, update, and delete dictionary entries.
#
# Create a dictionary `sensor_config` representing the configuration of sensor S1:
#
# ```
# id: "S1"
# location: "Northwest column, level 2"
# sampling_rate_hz: 1.0
# temp_range_c: (-20.0, 60.0)   ← a tuple
# active: True
# ```
#
# Then:
# 1. Print the entire dictionary.
# 2. Print just the `location`.
# 3. Try to access a key `"firmware_version"` safely using `.get()` with a default of `"unknown"`.
# 4. Add a new key `"firmware_version"` with value `"2.1.4"`.
# 5. Update `sampling_rate_hz` to `0.5`.
# 6. Delete the `active` key.
# 7. Iterate over all key-value pairs and print them in a formatted way.

# %%
# TODO: Create sensor_config dictionary

# TODO 1: Print the whole dict

# TODO 2: Print location

# TODO 3: Safe access for firmware_version

# TODO 4: Add firmware_version

# TODO 5: Update sampling_rate_hz

# TODO 6: Delete active

# TODO 7: Iterate with .items() and print formatted

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 5 — Dictionary of Lists: Grouping Data by Sensor
#
# **Objective**: Build a dictionary whose values are lists (a common pattern for grouping).
#
# From `sensor_data`, build a dictionary called `grouped` where:
# - Keys are sensor IDs: `"S1"` and `"S2"`.
# - Values are lists of valid (non-ERROR) temperature readings for that sensor.
#
# Then for each sensor, print:
# - The number of valid readings.
# - The minimum, maximum, and average temperature.
#
# Expected structure:
# ```python
# grouped = {
#     "S1": [22.3, 22.8, 23.2, 23.5, 24.0],
#     "S2": [23.1, 23.4, 24.1, 24.3]
# }
# ```

# %%
# TODO: Initialise grouped with empty lists for S1 and S2
grouped = {"S1": [], "S2": []}

# TODO: Loop through sensor_data, skip ERROR rows,
# and append each temperature_c to the correct list in grouped.

# TODO: For each sensor, print count, min, max, average.
# Use a for loop over grouped.items().

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 6 — Summary Report: Lists + Dicts Combined
#
# **Objective**: Build a structured summary dictionary from the sensor data.
#
# Create a `summary` dictionary with this structure:
# ```python
# summary = {
#     "total_records": ...,
#     "error_records": ...,
#     "valid_records": ...,
#     "S1": {
#         "count": ...,
#         "avg_temp_c": ...,
#         "min_temp_c": ...,
#         "max_temp_c": ...
#     },
#     "S2": {
#         "count": ...,
#         "avg_temp_c": ...,
#         "min_temp_c": ...,
#         "max_temp_c": ...
#     }
# }
# ```
#
# Then print the summary in a readable format.

# %%
# Reuse the 'grouped' dict from Exercise 5 (must run Exercise 5 first)

# TODO: Compute total, error, and valid record counts from sensor_data

# TODO: Build summary dict using the structure shown above
# For each sensor key, build a nested dict with count, avg, min, max
# Use the lists in grouped[sensor_id] for this

# TODO: Print the summary in a readable format

# Your code here:

# %% [markdown]
# ---
#
# ## Stretch Goal — Anomaly Detection
#
# Write a program that performs basic anomaly detection on the sensor data.
#
# 1. Compute the mean (average) and standard deviation of all valid temperatures across both sensors. Standard deviation: `sigma = sqrt(sum((x - mean)^2 for x in values) / n)` — implement this without any external libraries.
# 2. Define an anomaly as any reading more than 2 standard deviations from the mean.
# 3. Build an `anomalies` list containing the full records (dicts) of any anomalous readings.
# 4. Print the mean, standard deviation, and any detected anomalies.
# 5. Build a dictionary `anomaly_report` that maps each sensor_id to the list of anomalous readings for that sensor.
#
# > **Hint for standard deviation**: First compute the mean. Then build a list of squared deviations. Use `sum()` and `len()` — do not use `math.sqrt` or any statistics library (you may use `** 0.5` for square root).

# %%
# STRETCH GOAL — Anomaly Detection
import math

# TODO: Collect all valid temperatures

# TODO: Compute mean

# TODO: Compute standard deviation (implement from formula)

# TODO: Find anomalies (more than 2 sigma from mean)

# TODO: Print results

# TODO: Build anomaly_report dict

# Your code here:
