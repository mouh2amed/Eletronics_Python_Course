# %% [markdown]
# # TP 1 — Getting Started with Python
#
# **Module**: Programmation Python — ELNI 5.5
# **Chapter**: 1 — Getting Started
# **Estimated time**: 60–90 minutes
#
# ---
#
# ## Scenario
#
# You are starting your first day as a junior data analyst in a civil engineering consultancy. Your team uses Python for calculation automation and data processing. Before you can contribute to any real project, you must demonstrate that your development environment is correctly set up and that you can perform basic Python operations.
#
# Your supervisor has given you a checklist of tasks. Complete each one, making sure every code cell runs without errors before moving on.
#
# ---
#
# ## Instructions
#
# - Read the scenario description for each exercise.
# - Fill in the code where you see `# TODO`.
# - Run each cell with `Shift+Enter` to verify your answer.
# - Do not modify any code outside the `# TODO` sections unless instructed.

# %% [markdown]
# ---
#
# ## Exercise 1 — Verify Your Python Installation
#
# **Objective**: Use the `sys` module to confirm that Python 3.12 (or later) is running.
#
# Your supervisor needs a report confirming the Python version on your workstation.
#
# **Expected output** (version numbers will match your installation):
# ```
# Python version : 3.12.x
# Major version  : 3
# Minor version  : 12
# Executable     : /path/to/python
# ```

# %%
import sys

# TODO: Print the full Python version string using sys.version
# TODO: Print the major version number using sys.version_info.major
# TODO: Print the minor version number using sys.version_info.minor
# TODO: Print the path to the Python executable using sys.executable

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 2 — Working Directory Awareness
#
# **Objective**: Use the `os` module to inspect the current working directory.
#
# When Python scripts load files, they look relative to the **current working directory** (CWD). Engineers frequently encounter "file not found" errors because they forget to check the CWD first.
#
# **Expected output**:
# ```
# Current working directory: C:\Users\...\python-programming-course\chapters\01-getting-started\lab
# ```
# (The exact path depends on where you saved the course files.)

# %%
import os

# TODO: Store the current working directory in a variable called 'cwd'
# Hint: use os.getcwd()

# TODO: Print the cwd with a descriptive label using an f-string

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 3 — Your First print() Statements
#
# **Objective**: Use `print()` to display a structured welcome message.
#
# Write a short welcome message for a new user of your engineering team's Python environment. The output must span at least 3 lines and include:
# - The team or project name (you can invent one).
# - The Python version being used.
# - A short instruction for the user.
#
# **Example output**:
# ```
# ========================================
#   Algerian Engineering Consultancy — Python Environment
#   Python 3.12 | Ready for use
#   Run 'jupyter lab' to open the lab notebooks.
# ========================================
# ```

# %%
import sys

# TODO: Print a formatted welcome banner using print() statements.
# Include: separator lines, team name, Python version, and one instruction.
# Use f-strings where you insert the actual Python version.

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 4 — REPL-Style Arithmetic
#
# **Objective**: Practice using Python as a calculator in the REPL/notebook style.
#
# The REPL is useful for quick calculations. Your supervisor has asked you to compute three engineering quantities. For each one, write a single expression (no variable assignments) and let Jupyter display the result automatically.
#
# **Calculations to perform**:
# 1. A concrete column has a cross-sectional area of 0.25 m². If the allowable compressive stress is 20 MPa (= 20 × 10⁶ Pa), what is the maximum load in Newtons? (Load = stress × area)
# 2. Convert 350 km/h to m/s. (Divide by 3.6)
# 3. What is 2 raised to the power 10? (Python uses `**` for exponentiation)
#
# Put each expression in a separate cell so Jupyter displays each result.

# %%
# TODO: Calculation 1 — maximum load on the concrete column (in Newtons)
# Allowable stress = 20e6 Pa, Area = 0.25 m²

# %%
# TODO: Calculation 2 — convert 350 km/h to m/s

# %%
# TODO: Calculation 3 — compute 2 to the power of 10

# %% [markdown]
# ---
#
# ## Exercise 5 — IDLE Workflow Practice (Written Response)
#
# **Objective**: Demonstrate understanding of the IDLE shell vs script editor workflow.
#
# This exercise does not require code. Edit the Markdown cell below by replacing the `???` with correct answers.
#
# Alternatively, open IDLE on your machine and actually perform the steps described.

# %% [markdown]
# ### Answers to IDLE Questions
#
# 1. The keyboard shortcut to run a script in IDLE is: **???**
#
# 2. To open the IDLE script editor from the shell window, you use the menu: **??? → ???**
#
# 3. The IDLE shell displays the Python prompt: **???**
#
# 4. If you define `x = 100` in the IDLE shell and then close IDLE, the variable `x` when you reopen IDLE will be: **???** (still defined / no longer defined)
#
# 5. The difference between running a script with F5 in IDLE vs typing the same code directly in the shell is: **???**

# %% [markdown]
# ---
#
# ## Exercise 6 — IEP Historical Investigation
#
# **Objective**: Research and document the IEP tool and its modern replacements.
#
# Based on the lecture notes and the `docs/environment-setup.md` file in this repository, fill in the Markdown table below.

# %% [markdown]
# ### IEP vs Modern Tools
#
# | Feature | IEP | JupyterLab | VS Code + Python |
# |---|---|---|---|
# | Interactive shell | Yes | ??? | ??? |
# | Script editor | ??? | ??? | Yes |
# | Variable explorer | Yes | ??? | ??? |
# | Currently maintained | ??? | Yes | Yes |
# | Last major release (approx.) | ??? | Ongoing | Ongoing |
#
# **Why is IEP not recommended for new installations in 2026?**
#
# *Write your answer here (2–3 sentences):*
#
# ???

# %% [markdown]
# ---
#
# ## Exercise 7 — Jupyter Notebook Mechanics
#
# **Objective**: Demonstrate competency with Jupyter cell types and shortcuts.
#
# Complete the following mini-tasks inside this notebook:
#
# **Task A**: In the code cell below, write a Python expression that computes the perimeter of a rectangle with length 12.5 m and width 4.8 m. Let Jupyter display the result automatically (no `print()`).
#
# **Task B**: Below that, add a new Markdown cell (use `Esc` then `B`, then `Esc` then `M`) and write a one-sentence explanation of your calculation.
#
# **Task C**: In the final code cell below, write `import sys` and then in the same cell print `sys.version_info`. Confirm that both lines run correctly in a single cell.

# %%
# Task A — TODO: compute the perimeter of the rectangle
# length = 12.5 m, width = 4.8 m
# Perimeter = 2 * (length + width)
# Write ONE expression and let Jupyter display the result.

# %%
# Task C — TODO: import sys and print sys.version_info in the same cell

# %% [markdown]
# ---
#
# ## Stretch Goal — Environment Report Script
#
# Write a complete Python program (in the cell below) that prints a comprehensive environment report. The report must include:
#
# 1. Python version (major.minor.micro).
# 2. Platform (operating system identifier).
# 3. Path to the Python executable.
# 4. Current working directory.
# 5. A list of all items in the current directory (use `os.listdir('.')`).
# 6. Total number of items listed.
#
# Format the output neatly with labels aligned using f-string formatting (e.g., `f"{'Label':<25}: {value}"`). The `:<25` format specifier left-aligns within a field of width 25.
#
# **Example output structure**:
# ```
# === Python Environment Report ===
# Python version           : 3.12.0
# Platform                 : win32
# Executable               : C:\...\python.exe
# Working directory        : C:\...\lab
# Directory contents       :
#   - 01-tp-getting-started.ipynb
#   - 01-tp-solutions.ipynb
# Total items              : 2
# ```

# %%
# STRETCH GOAL — Environment Report
import sys
import os

# TODO: Implement the full environment report as described above.

# Your code here:
