# %% [markdown]
# # TP 4 — Functions
#
# **Module**: Programmation Python — ELNI 5.5
# **Chapter**: 4 — Functions
# **Estimated time**: 90–120 minutes
#
# ---
#
# ## Scenario
#
# Your team is building a **Python calculation library** for structural and geotechnical engineering. The goal is to replace a growing collection of scattered, one-off scripts with a well-organised library of reusable, well-documented functions.
#
# In this lab you will implement the first set of library functions, covering: unit conversion, geometric calculations, data processing, and reporting tools.

# %% [markdown]
# ---
#
# ## Exercise 1 — Built-in Functions: Statistics Summary
#
# **Objective**: Use built-in functions to compute a statistical summary.
#
# Given the stress readings below (in MPa), use **only Python built-in functions** (no imports) to compute and print:
# 1. Count (`len`)
# 2. Minimum (`min`)
# 3. Maximum (`max`)
# 4. Sum (`sum`)
# 5. Mean (sum/count)
# 6. The value closest to the mean — use `min()` with a `key=` argument: `min(data, key=lambda x: abs(x - mean))`
# 7. The three smallest values using `sorted()` and slicing

# %%
stress_mpa = [187.3, 193.1, 185.7, 201.4, 196.2, 189.8, 204.1, 192.6, 188.5, 197.9]

# TODO 1: count

# TODO 2: minimum

# TODO 3: maximum

# TODO 4: sum

# TODO 5: mean

# TODO 6: closest to mean using min() with key=

# TODO 7: three smallest using sorted() and slicing

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 2 — Parameterless Function
#
# **Objective**: Define and call simple functions with no parameters.
#
# 1. Define a parameterless function `print_report_header()` that prints a standardised report header with a title and a horizontal separator line. The title should say `"Engineering Calculations — ELNI 5.5"`.
#
# 2. Define a parameterless function `gravitational_acceleration()` that **returns** the value `9.81` (standard gravity in m/s²). This function should have a docstring.
#
# 3. Call both functions. Store the return value of `gravitational_acceleration()` in a variable `g` and use it to compute the weight of a 500 kg mass.
#
# 4. Verify you understand the print-vs-return difference: what would happen if `gravitational_acceleration()` used `print(9.81)` instead of `return 9.81`? Write your answer as a comment.

# %%
# TODO: Define print_report_header()


# TODO: Define gravitational_acceleration()


# TODO: Call both functions and compute the weight of 500 kg

# TODO: Add a comment explaining what happens with print vs return

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 3 — Functions with Parameters
#
# **Objective**: Write functions with multiple parameters and clear docstrings.
#
# Implement the following functions. Each must have a complete docstring.
#
# 1. `moment_of_inertia_rect(width_m, height_m)` — returns the second moment of area of a rectangular cross-section about the neutral axis: `I = b × h³ / 12`.
#
# 2. `reynolds_number(velocity_ms, diameter_m, density_kg_m3, viscosity_pa_s)` — returns the Reynolds number: `Re = (v × d × ρ) / μ`.
#
# 3. `classify_flow(re)` — returns the string `"Laminar"` if Re < 2300, `"Transitional"` if 2300 ≤ Re ≤ 4000, or `"Turbulent"` otherwise.
#
# 4. Test all three functions with appropriate values and print the results.

# %%
# TODO: Define moment_of_inertia_rect(width_m, height_m)


# TODO: Define reynolds_number(velocity_ms, diameter_m, density_kg_m3, viscosity_pa_s)


# TODO: Define classify_flow(re)


# TODO: Test the functions
# Test 1: Rectangular section 200 mm wide, 400 mm deep
# Test 2: Water at 20°C (density=998, viscosity=1.002e-3), pipe d=50mm, v=0.5 m/s

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 4 — Default Parameters
#
# **Objective**: Use default parameter values to make functions flexible.
#
# 1. Write a function `format_engineering_value(value, unit, precision=3, width=12)` that returns a formatted string like `"  22.300 °C"`. The `unit` is required; `precision` defaults to 3; `width` defaults to 12.
#
# 2. Write a function `beam_deflection(force_n, span_m, E=200e9, I=8.33e-5)` that computes the midspan deflection of a simply-supported beam under a central point load:
#    `δ = F × L³ / (48 × E × I)`
#    The Young's modulus `E` defaults to steel (200 GPa) and the second moment `I` defaults to a typical W-section. The function should return the deflection in metres.
#
# 3. Call `beam_deflection` three ways: using only required arguments, overriding `E` for a concrete beam (E = 30 GPa), and overriding both `E` and `I`.

# %%
# TODO: Define format_engineering_value(value, unit, precision=3, width=12)


# TODO: Test format_engineering_value with different arguments


# TODO: Define beam_deflection(force_n, span_m, E=200e9, I=8.33e-5)


# TODO: Call beam_deflection three ways:
# 1. Steel beam defaults: force=50000 N, span=6.0 m
# 2. Concrete beam: E=30e9 (override)
# 3. Custom beam: E=70e9 (aluminium), I=2.5e-5

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 5 — Assigning Functions to Variables
#
# **Objective**: Demonstrate first-class function behaviour.
#
# 1. Define three temperature conversion functions: `to_fahrenheit(c)`, `to_kelvin(c)`, `to_rankine(c)` (Rankine = K × 9/5).
#
# 2. Create a dictionary `converters` mapping unit names to function objects:
#    ```python
#    converters = {"F": to_fahrenheit, "K": to_kelvin, "Ra": to_rankine}
#    ```
#
# 3. Write a function `batch_convert(temp_c, target_units)` that takes a Celsius temperature and a list of unit strings (e.g., `["F", "K"]`), looks up each converter in the `converters` dictionary, and returns a dictionary mapping unit string to converted value.
#
# 4. Test with `batch_convert(100.0, ["F", "K", "Ra"])` and print the results.

# %%
# TODO: Define to_fahrenheit, to_kelvin, to_rankine


# TODO: Create converters dict


# TODO: Define batch_convert(temp_c, target_units)


# TODO: Test with 100.0 °C converting to F, K, Ra

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 6 — Variadic Functions (*args and **kwargs)
#
# **Objective**: Write and use functions with `*args` and `**kwargs`.
#
# 1. Write a function `channel_statistics(*channel_readings)` that accepts any number of positional arguments (each is a float temperature reading) and returns a dictionary with keys `"count"`, `"mean"`, `"min"`, `"max"`. If no arguments are given, return all values as `None`.
#
# 2. Write a function `build_sensor_record(sensor_id, timestamp, **measurements)` that takes a required sensor ID, a required timestamp, and any number of keyword measurement arguments (e.g., `temperature_c=22.3`, `pressure_kpa=101.2`). The function should return a dictionary combining all the information.
#
# 3. Test both functions.

# %%
# TODO: Define channel_statistics(*channel_readings)


# TODO: Test channel_statistics with 0, 1, and 5 arguments


# TODO: Define build_sensor_record(sensor_id, timestamp, **measurements)


# TODO: Test build_sensor_record with various measurements
# Example: build_sensor_record("S1", "2024-01-15 08:00:00",
#                               temperature_c=22.3, pressure_kpa=101.2, humidity_pct=65.0)

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 7 — Mutable vs Immutable: Predict and Verify
#
# **Objective**: Understand how Python handles mutable and immutable arguments.
#
# For each function below, **predict** the output *before* running the cell. Write your prediction as a comment, then run to verify.
#
# **Part A** — Immutable:
# ```python
# def double_value(n):
#     n = n * 2
#     return n
#
# x = 10
# result = double_value(x)
# print(x, result)
# ```
#
# **Part B** — Mutable (in-place):
# ```python
# def scale_all_inplace(values, factor):
#     for i in range(len(values)):
#         values[i] *= factor
#
# data = [1.0, 2.0, 3.0]
# scale_all_inplace(data, 10)
# print(data)
# ```
#
# **Part C** — Mutable (new list):
# ```python
# def scale_all_new(values, factor):
#     return [v * factor for v in values]
#
# data = [1.0, 2.0, 3.0]
# scaled = scale_all_new(data, 10)
# print(data, scaled)
# ```

# %%
# Part A — Prediction: x = ???, result = ???
def double_value(n):
    n = n * 2
    return n

x = 10
result = double_value(x)
print(x, result)

# %%
# Part B — Prediction: data = ???
def scale_all_inplace(values, factor):
    for i in range(len(values)):
        values[i] *= factor

data = [1.0, 2.0, 3.0]
scale_all_inplace(data, 10)
print(data)

# %%
# Part C — Prediction: data = ???, scaled = ???
def scale_all_new(values, factor):
    return [v * factor for v in values]

data = [1.0, 2.0, 3.0]
scaled = scale_all_new(data, 10)
print(data, scaled)

# %%
# TODO: Write a brief explanation (as a comment or markdown cell)
# Why does Part B modify data but Part C does not?
# Your explanation:

# %% [markdown]
# ---
#
# ## Exercise 8 — Scope: Local and Global
#
# **Objective**: Demonstrate understanding of local vs global scope.
#
# 1. Define a global constant `STEEL_DENSITY = 7850` (kg/m³).
#
# 2. Write a function `compute_mass(volume_m3)` that uses `STEEL_DENSITY` from global scope (without passing it as a parameter). It should return `volume_m3 * STEEL_DENSITY`.
#
# 3. Inside `compute_mass`, also define a local variable called `density` that shadows the global (set it to `7850` too). Print the local `density` inside the function. Then try to print `density` outside the function — observe the `NameError`.
#
# 4. Write a function `increment_counter()` that increments a global counter variable using the `global` keyword. Call it 5 times and print the final counter value.
#
# 5. Write a brief comment explaining why relying on `global` for mutable state is generally discouraged.

# %%
STEEL_DENSITY = 7850  # kg/m³

# TODO: Define compute_mass(volume_m3) using STEEL_DENSITY from global scope


# TODO: Call compute_mass with volume = 0.01 m³ and print the result


# TODO: Try accessing 'density' outside the function — what happens?
# (Use a try/except to catch NameError and print a message explaining why)

# Your code here:

# %%
# TODO: Define a global counter and increment_counter() using global keyword
call_count = 0

# def increment_counter(): ...

# TODO: Call 5 times and print result

# TODO: Comment on why this approach is discouraged in larger programs

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 9 — Lambda Functions
#
# **Objective**: Write and use lambda functions.
#
# 1. Write a lambda `to_mpa` that converts a value from Pascals to MPa (divide by 1e6). Test it.
#
# 2. Sort the `sensor_records` list below by `pressure_kpa` in descending order using `sorted()` with a `key=lambda` argument.
#
# 3. Find the record with the highest temperature using `max()` with a `key=lambda`.
#
# 4. Use `filter()` with a lambda to create a list of records where the status is `"OK"`.
#
# 5. Use `map()` with a lambda to create a list of temperature values in Fahrenheit from the OK records.

# %%
sensor_records = [
    {"sensor_id": "S1", "temperature_c": 22.3, "pressure_kpa": 101.2, "status": "OK"},
    {"sensor_id": "S2", "temperature_c": -999.0, "pressure_kpa": 101.6, "status": "ERROR"},
    {"sensor_id": "S1", "temperature_c": 23.5, "pressure_kpa": 101.0, "status": "OK"},
    {"sensor_id": "S2", "temperature_c": 24.1, "pressure_kpa": 101.7, "status": "OK"},
    {"sensor_id": "S1", "temperature_c": 24.0, "pressure_kpa": 100.9, "status": "OK"},
]

# TODO 1: Define to_mpa lambda and test it

# TODO 2: Sort by pressure descending

# TODO 3: Find record with highest temperature using max()

# TODO 4: Filter to OK records using filter() + lambda

# TODO 5: Map OK records to Fahrenheit using map() + lambda

# Your code here:

# %% [markdown]
# ---
#
# ## Stretch Goal — Engineering Function Library
#
# Build a mini engineering library with the following functions. Each must:
# - Have a complete NumPy-style docstring.
# - Handle invalid inputs with a `ValueError` and a descriptive message.
# - Be tested with at least two test cases.
#
# **Functions to implement**:
#
# 1. `hydraulic_diameter(area_m2, wetted_perimeter_m)` — returns 4A/P.
# 2. `pipe_velocity(flow_rate_m3s, diameter_m)` — returns Q / (π × (d/2)²).
# 3. `friction_loss(velocity_ms, length_m, diameter_m, friction_factor)` — Darcy-Weisbach: `h_f = f × (L/D) × (v² / (2g))` where g = 9.81.
# 4. `full_pipe_analysis(flow_rate_m3s, diameter_m, length_m, friction_factor, density=998.0, viscosity=1.002e-3)` — calls the above three functions and returns a summary dictionary.
#
# The `full_pipe_analysis` function demonstrates the use of default parameters and passing functions as values.

# %%
import math

# STRETCH GOAL — Engineering Function Library
# TODO: Implement all four functions with docstrings and error handling

# Your code here:
