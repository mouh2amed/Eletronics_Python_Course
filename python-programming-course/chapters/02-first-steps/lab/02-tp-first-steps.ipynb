# %% [markdown]
# # TP 2 — First Steps in Python
#
# **Module**: Programmation Python — ELNI 5.5
# **Chapter**: 2 — First Steps
# **Estimated time**: 90–120 minutes
#
# ---
#
# ## Scenario
#
# You are working on a field measurement campaign for a structural engineering project. Your team needs several short Python programs:
#
# 1. A unit-conversion calculator for field measurements.
# 2. An output formatter for sensor readings.
# 3. A variable-type inspector for incoming data streams.
# 4. A string parser for log-file entries.
# 5. A load-classification decision tool.
# 6. A loop-based table generator for design calculations.
# 7. An interactive input program for data entry.
#
# Each exercise below corresponds to one of these programs. Work through them in order.

# %% [markdown]
# ---
#
# ## Exercise 1 — Arithmetic: Unit Conversion Calculator
#
# **Objective**: Practice Python arithmetic operators.
#
# Implement unit conversions commonly needed on a construction site. For each calculation, assign the result to a well-named variable and print a formatted result.
#
# **Conversions to implement**:
# 1. 250 mm to metres (divide by 1000)
# 2. 12.5 kN to Newtons (multiply by 1000)
# 3. 45 MPa to Pascals (multiply by 10⁶, use `1e6`)
# 4. The area of a circular column cross-section with diameter 400 mm (area = π × r²; use `math.pi`)
# 5. The floor division and remainder of dividing 1350 seconds by 60 (to find minutes and leftover seconds)
#
# **Expected output** (example values):
# ```
# 250 mm = 0.250 m
# 12.5 kN = 12500.000 N
# 45 MPa = 45000000.000 Pa
# Column area (d=400 mm) = 0.125664 m²
# 1350 s = 22 min 30 s
# ```

# %%
import math

# TODO 1: Convert 250 mm to metres

# TODO 2: Convert 12.5 kN to Newtons

# TODO 3: Convert 45 MPa to Pascals

# TODO 4: Compute the area of a circular column with diameter 400 mm
# Remember: diameter = 400 mm = 0.400 m, radius = diameter / 2

# TODO 5: Compute floor division and remainder of 1350 // 60 and 1350 % 60

# TODO: Print all results with descriptive labels using f-strings

# %% [markdown]
# ---
#
# ## Exercise 2 — Formatted Output
#
# **Objective**: Use `print()` with f-strings and format specifiers to produce an aligned report.
#
# Given the sensor data below, produce a formatted table. The table must have:
# - A title row
# - A separator line
# - Each sensor on its own line with aligned columns
# - Temperature formatted to 1 decimal place
# - Pressure formatted to 2 decimal places
# - Status left-aligned
#
# **Expected output**:
# ```
# ============================================
#   Sensor Report — 2024-01-15 08:00:00
# ============================================
# Sensor   Temp (°C)   Pressure (kPa)   Status
# --------------------------------------------
# S1         22.3           101.20      OK
# S2         23.1           101.50      OK
# S3         -999.0         101.60      ERROR
# --------------------------------------------
# ```

# %%
# Given data — do not modify
timestamp = "2024-01-15 08:00:00"
sensors = ["S1", "S2", "S3"]
temperatures = [22.3, 23.1, -999.0]
pressures = [101.20, 101.50, 101.60]
statuses = ["OK", "OK", "ERROR"]

# TODO: Print the header

# TODO: Print the column headings

# TODO: Loop through the three sensors and print each row
# Use zip() to iterate over all lists simultaneously:
# for s, t, p, st in zip(sensors, temperatures, pressures, statuses):

# TODO: Print a footer separator

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 3 — Variables and Types
#
# **Objective**: Assign variables of different types and perform type inspection and conversion.
#
# A data parsing function receives strings from a sensor data stream. Parse each string into the correct Python type and print the result with its type name.
#
# Given these raw strings from the stream:
# - `"42"` — should become an `int` (sample count)
# - `"22.85"` — should become a `float` (temperature)
# - `"OK"` — stays a `str` (status)
# - `"1"` — should become a `bool` (active flag: 1 means True)
# - `""` — should become `None` (missing reading)
#
# For each, print: `raw: '{raw}' → value: {value} (type: {type_name})`

# %%
# Given raw strings
raw_count = "42"
raw_temp = "22.85"
raw_status = "OK"
raw_flag = "1"
raw_missing = ""

# TODO: Convert raw_count to int, print with type

# TODO: Convert raw_temp to float, print with type

# TODO: raw_status stays as str, print with type

# TODO: Convert raw_flag to bool via int first: bool(int(raw_flag)), print with type

# TODO: raw_missing should become None (if empty string, set to None), print with type
# Hint: use 'if raw_missing else None'

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 4 — Strings: Log File Parser
#
# **Objective**: Use string indexing, slicing, and methods to parse structured text.
#
# Each line in the `sample_log.txt` file has this format:
# ```
# [2024-01-15 08:00:00] INFO  System started
# ```
#
# Write code that, given the log line below, extracts:
# 1. The date (characters 1–10, inside the brackets)
# 2. The time (characters 12–19)
# 3. The log level (the word after `]` — split on whitespace)
# 4. The message (everything after the log level)
#
# Additionally:
# 5. Check if the log level is `"ERROR"` and print a warning if so.
# 6. Count how many words are in the message.
# 7. Replace `"S2"` with `"SENSOR_2"` in the message if it appears.

# %%
# Given log lines
line1 = "[2024-01-15 08:16:00] ERROR  Failed to read S2: value below threshold"
line2 = "[2024-01-15 08:00:00] INFO  System started"

# Work with line1 for parts 1-5, then apply the same logic to line2 for validation

# TODO 1: Extract the date (slice characters 1 through 10)

# TODO 2: Extract the time (slice characters 12 through 19)

# TODO 3 & 4: Split the line on whitespace, extract level and message
# Hint: parts = line1.split()
# The format is: [date time] LEVEL message_words...
# After split: parts[0]='[2024-01-15', parts[1]='08:16:00]', parts[2]='ERROR', parts[3:]= message

# TODO 5: Check if level == 'ERROR' and print a warning

# TODO 6: Count words in the message (use len() on the split list)

# TODO 7: Replace 'S2' with 'SENSOR_2' in the message

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 5 — Conditionals: Structural Load Classifier
#
# **Objective**: Use `if`/`elif`/`else` and boolean operators for a design decision.
#
# Implement a **load classification function** for a structural member. Given an applied load in kN and an allowable load in kN, classify the member according to this table:
#
# | Load ratio (applied / allowable) | Classification |
# |---|---|
# | ratio < 0 | Invalid (load cannot be negative) |
# | 0 ≤ ratio < 0.5 | Under-designed |
# | 0.5 ≤ ratio < 0.8 | Acceptable |
# | 0.8 ≤ ratio ≤ 1.0 | Near capacity — review |
# | ratio > 1.0 | OVERSTRESSED |
#
# Test your logic with at least four different load values: 20, 75, 95, and 120 kN, all against an allowable of 100 kN.

# %%
allowable_kn = 100.0
test_loads_kn = [20.0, 75.0, 95.0, 120.0, -5.0]

for applied_kn in test_loads_kn:
    # TODO: Compute the load ratio

    # TODO: Use if/elif/else to determine the classification string

    # TODO: Print the result in this format:
    # "Applied = XXX.X kN | Ratio = X.XX | Classification: ..."

    pass  # Remove this 'pass' when you add your code

# %% [markdown]
# ---
#
# ## Exercise 6 — Loops: Design Table Generator
#
# **Objective**: Use `for` and `while` loops with `range()` to generate tabular output.
#
# ### Part A — for loop
# Generate a **Reynolds number table** for pipe flow. The Reynolds number is:
#
# Re = (velocity × diameter × density) / dynamic_viscosity
#
# For water at 20°C: density = 998 kg/m³, dynamic_viscosity = 1.002 × 10⁻³ Pa·s, pipe diameter = 0.05 m.
#
# Compute Re for velocities 0.1, 0.2, 0.3, ..., 1.0 m/s (use `range()` with appropriate step or a list). For each, also classify the flow: Re < 2300 → Laminar, Re > 4000 → Turbulent, else → Transitional.
#
# ### Part B — while loop
# A concrete cylinder is tested under compression. Load increases in steps of 5 kN, starting at 0 kN, until the stress exceeds 30 MPa (the failure threshold). The cylinder diameter is 150 mm.
#
# Print each load step and its corresponding stress. Stop when the failure threshold is exceeded, and print which load caused failure.

# %%
import math

# Part A — Reynolds number table
density = 998.0          # kg/m³
viscosity = 1.002e-3     # Pa·s
diameter = 0.05          # m

print(f"{'Velocity (m/s)':<18} {'Re':>10} {'Flow regime':<15}")
print("-" * 45)

# TODO: Loop velocity from 0.1 to 1.0 in steps of 0.1
# Hint: use [v/10 for v in range(1, 11)] or a for loop with a list
# For each velocity:
#   - Compute Reynolds number
#   - Classify as Laminar / Transitional / Turbulent
#   - Print a formatted row

# Your code here:

# %%
# Part B — while loop: compression test
FAILURE_STRESS_PA = 30e6   # 30 MPa
diameter_m = 0.150         # 150 mm cylinder
load_step_kn = 5.0

# TODO: Compute the cross-sectional area
# TODO: Initialise load_kn = 0.0, stress = 0.0
# TODO: while stress <= FAILURE_STRESS_PA:
#     increase load by load_step_kn
#     compute stress = (load in N) / area
#     print load and stress
# After the loop, print which load caused failure

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 7 — Keyboard Input: Interactive Converter
#
# **Objective**: Use `input()` with type conversion to build an interactive tool.
#
# Write an **interactive temperature converter** that:
# 1. Asks the user to enter a temperature value (number).
# 2. Asks the user to enter the source unit (`C`, `F`, or `K`).
# 3. Converts the temperature to all three scales.
# 4. Prints the results.
#
# Conversion formulas:
# - °F = °C × 9/5 + 32
# - K = °C + 273.15
# - °C = (°F − 32) × 5/9
# - °C = K − 273.15
#
# **Sample interaction** (user types the indented values):
# ```
# Enter temperature value: 100
# Enter unit (C/F/K): C
#
# Conversion results:
#   100.00 °C = 212.00 °F = 373.15 K
# ```
#
# > **Note**: In Jupyter, `input()` opens a text box at the bottom of the cell. If it does not work in your environment, replace the `input()` calls with fixed values for testing (as shown in the lecture notebook).

# %%
# TODO: Uncomment the input() lines when running as a script or if your Jupyter supports it.
# For testing in Jupyter, use the fixed values provided.

# raw_value = input("Enter temperature value: ")
# unit = input("Enter unit (C/F/K): ")

# Fixed test values — change these to test different cases:
raw_value = "100"
unit = "C"

# TODO: Convert raw_value to float

# TODO: Convert unit to uppercase (in case user types lowercase)

# TODO: Use if/elif/else to handle each source unit
# For each case, compute temp_c, temp_f, temp_k

# TODO: Print the results

# Your code here:

# %% [markdown]
# ---
#
# ## Stretch Goal — Combined Pipeline
#
# You are given a list of raw sensor readings as strings (as they might arrive from a data stream). Each string has the format `"S1:22.3:OK"` (sensor_id:temperature:status).
#
# Write a program that:
# 1. Parses each string into its three components using `.split(':')`.
# 2. Converts the temperature to float.
# 3. Skips any reading with `status == "ERROR"` or temperature below −100 (use `continue`).
# 4. For valid readings, compute the temperature in Fahrenheit.
# 5. Prints a formatted table of all valid readings including the Fahrenheit conversion.
# 6. After the loop, prints the count of valid readings and their average temperature.
# 7. Uses a `while` loop (with a counter) instead of a `for` loop as an alternative implementation.
#
# Input data:
# ```python
# raw_readings = [
#     "S1:22.3:OK",
#     "S2:-999.0:ERROR",
#     "S3:23.1:OK",
#     "S1:22.8:OK",
#     "S2:24.1:OK",
#     "S3:23.5:OK"
# ]
# ```

# %%
raw_readings = [
    "S1:22.3:OK",
    "S2:-999.0:ERROR",
    "S3:23.1:OK",
    "S1:22.8:OK",
    "S2:24.1:OK",
    "S3:23.5:OK"
]

# STRETCH GOAL — TODO: Implement the pipeline described above.
# Part 1: for loop version

# Part 2: while loop version (optional extra challenge)

# Your code here:
