# %% [markdown]
# # TP 5 — Files and Exception Handling
#
# **Module**: Programmation Python — ELNI 5.5
# **Chapter**: 5 — Files and Exception Handling
# **Estimated time**: 90–120 minutes
#
# ---
#
# ## Scenario
#
# You are the lead data engineer for a field monitoring campaign. Your monitoring system produces two files daily:
# - `sensor_data.csv` — temperature and pressure readings every 15 minutes.
# - `sample_log.txt` — system event log with INFO, WARNING, and ERROR entries.
#
# Your task is to:
# 1. Navigate the filesystem to find these files.
# 2. Read and parse both files.
# 3. Process the data and generate a summary report.
# 4. Copy the processed data to an output directory.
# 5. Write the summary to a file.
# 6. Add robust error handling throughout.
#
# ---
#
# ## Setup — Path Configuration
#
# Run this cell first to set up the file paths. The `assets/` directory is two levels above this notebook.

# %%
import os

# Paths — adjust if needed for your system
NOTEBOOK_DIR = os.getcwd()
ASSETS_DIR = os.path.join(NOTEBOOK_DIR, '..', '..', 'assets')
OUTPUT_DIR = os.path.join(NOTEBOOK_DIR, '..', '..', 'output')

CSV_PATH = os.path.join(ASSETS_DIR, 'sensor_data.csv')
LOG_PATH = os.path.join(ASSETS_DIR, 'sample_log.txt')

# Verify assets exist
print(f"Notebook directory : {NOTEBOOK_DIR}")
print(f"Assets directory   : {os.path.abspath(ASSETS_DIR)}")
print(f"CSV exists         : {os.path.exists(CSV_PATH)}")
print(f"Log exists         : {os.path.exists(LOG_PATH)}")

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Output directory   : {os.path.abspath(OUTPUT_DIR)} (ready)")

# %% [markdown]
# ---
#
# ## Exercise 1 — Directory Navigation
#
# **Objective**: Use `os` functions to explore the filesystem.
#
# 1. Print the current working directory.
# 2. List all files and directories in the `assets/` directory.
# 3. For each item in `assets/`, print whether it is a file or directory, and if it is a file, print its size in bytes using `os.path.getsize()`.
# 4. Check if a file called `missing_data.csv` exists in `assets/`. Print an appropriate message for both cases.
# 5. Build the path to `sensor_data.csv` using `os.path.join()` and verify it is an absolute path using `os.path.abspath()`.

# %%
import os

# TODO 1: Print CWD

# TODO 2: List assets/ contents

# TODO 3: For each item, print type and size
# Hint: use os.path.isfile(), os.path.isdir(), os.path.getsize()

# TODO 4: Check for missing_data.csv

# TODO 5: Build path and get absolute path

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 2 — Reading the Log File
#
# **Objective**: Read a text file and extract information.
#
# 1. Open `sample_log.txt` using a `with` statement and read its contents.
# 2. Print the total number of lines.
# 3. Print each line that contains `"ERROR"` or `"WARNING"`.
# 4. Count how many lines contain `"INFO"`, how many contain `"WARNING"`, and how many contain `"ERROR"`. Print a summary.
# 5. Extract the timestamp from the first line using string slicing (characters 1–19 inside the brackets).

# %%
# TODO 1: Open LOG_PATH with 'with' and read all lines

# TODO 2: Print total line count

# TODO 3: Print ERROR and WARNING lines

# TODO 4: Count INFO, WARNING, ERROR lines and print summary

# TODO 5: Extract timestamp from first line

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 3 — Reading and Parsing the CSV File
#
# **Objective**: Use the `csv` module to read and parse structured data.
#
# 1. Open `sensor_data.csv` using `csv.DictReader` inside a `with` statement.
# 2. Parse each row into a dictionary with correctly-typed values (convert temperature and pressure to `float`).
# 3. Print the header fields (column names).
# 4. Print each record in a formatted table.
# 5. After loading, print: total record count, count of ERROR records, count of OK records.

# %%
import csv

# TODO 1 & 2: Open CSV_PATH with csv.DictReader, parse rows
sensor_records = []

# TODO 3: Print header fields

# TODO 4: Print formatted table
# Use this header format:
# Timestamp              Sensor   Temp (°C)   Pressure (kPa)   Status

# TODO 5: Print counts

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 4 — Writing Variables to a File
#
# **Objective**: Write processed data and computed results to text files.
#
# Using the `sensor_records` list from Exercise 3:
#
# 1. Compute the following statistics for all valid (non-ERROR) readings:
#    - Total valid records, records per sensor
#    - Average, minimum, and maximum temperature per sensor
#
# 2. Write a structured text report to `OUTPUT_DIR/sensor_report.txt` containing all the above statistics.
#
# 3. Read the file back and print its contents to verify.
#
# 4. Append a footer line to the file with the current date (use `"Report generated: 2024-01-15"` as a fixed string for reproducibility).

# %%
import os

# TODO 1: Compute statistics from sensor_records
# Hint: group by sensor_id and filter out ERROR rows

# TODO 2: Write report to OUTPUT_DIR/sensor_report.txt
report_path = os.path.join(OUTPUT_DIR, 'sensor_report.txt')

# TODO 3: Read back and print

# TODO 4: Append footer

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 5 — Copying Files
#
# **Objective**: Use `shutil` to copy files.
#
# 1. Copy `sensor_data.csv` from `assets/` to `output/` using `shutil.copy()`.
# 2. Verify the copy was created using `os.path.exists()`.
# 3. Compare the file sizes of the original and the copy using `os.path.getsize()`.
# 4. Copy `sample_log.txt` to `output/sample_log_backup.txt` using `shutil.copy2()` (preserves metadata).
# 5. Print the list of all files now in the `output/` directory.

# %%
import shutil
import os

# TODO 1: Copy sensor_data.csv to output/

# TODO 2: Verify copy exists

# TODO 3: Compare file sizes

# TODO 4: Copy log with shutil.copy2()

# TODO 5: List output/ directory

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 6 — Exception Handling: Robust File Reader
#
# **Objective**: Use `try/except/else/finally` to handle errors.
#
# 1. Write a function `safe_read_csv(filepath)` that:
#    - Tries to open and read the CSV.
#    - Catches `FileNotFoundError` and prints a message, returning an empty list.
#    - Catches `PermissionError` and prints a message, returning an empty list.
#    - For each row, wraps the type conversion in a `try/except ValueError` and skips malformed rows (printing a warning).
#    - Uses `else` to print a success message only if no exception occurred in the outer `try`.
#    - Uses `finally` to print `"Done attempting to read [filename]"` regardless.
#
# 2. Test `safe_read_csv` with:
#    - The actual `CSV_PATH` (should succeed).
#    - A path to a file that does not exist.
#
# 3. Write a function `safe_parse_float(value_str, field_name)` that tries `float(value_str)`, catching `ValueError` and returning `None` with a warning message.

# %%
import csv
import os

def safe_parse_float(value_str, field_name):
    """
    Parse a string to float, returning None on failure.

    Parameters
    ----------
    value_str : str
        String to convert.
    field_name : str
        Field name for the error message.

    Returns
    -------
    float or None
    """
    # TODO: Implement with try/except ValueError
    pass


def safe_read_csv(filepath):
    """
    Safely read sensor CSV data with full exception handling.

    Parameters
    ----------
    filepath : str
        Path to the CSV file.

    Returns
    -------
    list of dict
        Parsed records, or empty list on failure.
    """
    # TODO: Implement with try/except FileNotFoundError, PermissionError,
    # inner try/except ValueError per row, else, and finally.
    pass


# TODO: Test with CSV_PATH
print("=== Test 1: valid file ===")

# TODO: Test with nonexistent path
print("\n=== Test 2: missing file ===")

# Your code here:

# %% [markdown]
# ---
#
# ## Exercise 7 — Raising Exceptions
#
# **Objective**: Use `raise` to enforce input validation.
#
# Write a function `write_csv_report(records, output_filepath)` that:
# 1. Raises `ValueError` if `records` is empty.
# 2. Raises `TypeError` if `records` is not a list.
# 3. Raises `ValueError` if `output_filepath` does not end with `.csv`.
# 4. Otherwise, writes the records to a CSV file using `csv.DictWriter`.
# 5. Returns the number of records written.
#
# Test with:
# - A valid list of records → should succeed.
# - An empty list → should raise `ValueError`.
# - A file path ending in `.txt` → should raise `ValueError`.
# - The number `42` as records → should raise `TypeError`.
#
# Wrap each test call in a `try/except` to catch and print the errors.

# %%
import csv
import os

def write_csv_report(records, output_filepath):
    """
    Write a list of sensor records to a CSV file.

    Parameters
    ----------
    records : list of dict
        Sensor records to write.
    output_filepath : str
        Destination CSV file path (must end with .csv).

    Returns
    -------
    int
        Number of records written.

    Raises
    ------
    TypeError
        If records is not a list.
    ValueError
        If records is empty or output_filepath does not end with .csv.
    """
    # TODO: Validate inputs with raise

    # TODO: Write to CSV using csv.DictWriter

    # TODO: Return count of records written
    pass


# Reuse sensor_records from Exercise 3
test_output = os.path.join(OUTPUT_DIR, 'valid_output.csv')

# Test 1: Valid call
print("Test 1 — Valid records:")
try:
    # TODO: call write_csv_report with sensor_records and test_output
    pass
except (ValueError, TypeError) as e:
    print(f"  Error: {e}")

# Test 2: Empty list
print("Test 2 — Empty list:")
try:
    # TODO
    pass
except (ValueError, TypeError) as e:
    print(f"  Error: {e}")

# Test 3: Wrong extension
print("Test 3 — Wrong extension:")
try:
    # TODO
    pass
except (ValueError, TypeError) as e:
    print(f"  Error: {e}")

# Test 4: Non-list records
print("Test 4 — Non-list records:")
try:
    # TODO
    pass
except (ValueError, TypeError) as e:
    print(f"  Error: {e}")

# %% [markdown]
# ---
#
# ## Stretch Goal — End-to-End Pipeline
#
# Build a complete data processing pipeline as a single function `run_monitoring_pipeline(csv_path, log_path, output_dir)` that:
#
# 1. Reads the CSV file using `safe_read_csv()` from Exercise 6.
# 2. Reads the log file and counts errors/warnings.
# 3. Filters valid sensor readings.
# 4. Computes statistics per sensor (mean, min, max temperature).
# 5. Identifies any readings where temperature changed by more than 1°C between consecutive readings for the same sensor.
# 6. Writes a summary report to `output_dir/pipeline_report.txt` using all the above information.
# 7. Copies the original CSV to `output_dir/` as a backup.
# 8. Returns a summary dictionary.
# 9. Handles all exceptions properly — the pipeline should never crash; it should always write a report (even a failure report) using the `finally` clause.
#
# Test by calling:
# ```python
# result = run_monitoring_pipeline(CSV_PATH, LOG_PATH, OUTPUT_DIR)
# print(result)
# ```

# %%
import csv
import os
import shutil

def run_monitoring_pipeline(csv_path, log_path, output_dir):
    """
    Full data processing pipeline for monitoring data.

    Parameters
    ----------
    csv_path : str
        Path to the sensor CSV file.
    log_path : str
        Path to the system log file.
    output_dir : str
        Directory for output files.

    Returns
    -------
    dict
        Pipeline summary.
    """
    # TODO: Implement the full pipeline as described above.
    pass


# TODO: Test the pipeline
result = run_monitoring_pipeline(CSV_PATH, LOG_PATH, OUTPUT_DIR)
print(result)
